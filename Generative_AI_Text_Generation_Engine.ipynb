# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranayshukla0610/ML-projects-portfolio/blob/main/Generative_AI_Text_Generation_Engine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Generative AI!")

# %%
# !pip install transformers torch

# %%
from transformers import pipeline

# %%
generator = pipeline(
    "text-generation",
    model='gpt2'
)

# %%
prompt = "Artificial Intelligence is"

result = generator(
    prompt,
    max_length=50
)

print(result)

# %%
prompt = "Machine Learning is"

result = generator(
    prompt,
    max_length=60
)

generated_text = result[0]['generated_text']

print("Generated Text:\n")
print(generated_text)

# %%
prompt = "Deep Learning can"

result = generator(
    prompt,
    max_length=80,
    do_sample=True,
    temperature=0.9
)

print(result[0]['generated_text'])

# %%
print("AI TEXT GENERATOR")
print("Type 'exit' to stop")

while True:

    prompt = input("\nYou: ")

    if prompt.lower() == "exit":
        print("Goodbye!")
        break

    result = generator(
        prompt,
        max_length=80,
        do_sample=True,
        temperature=0.8
    )

    generated_text = result[0]['generated_text']

    print("\nAI:")
    print(generated_text)

# %%
from transformers import pipeline

# Load model
generator = pipeline(
    "text-generation",
    model="gpt2"
)

print("=" * 50)
print("WELCOME TO AI TEXT GENERATOR")
print("=" * 50)

while True:

    prompt = input("\nEnter Prompt: ")

    if prompt.lower() == "exit":
        print("\nExiting Program...")
        break

    try:

        results = generator(
            prompt,
            max_length=100,
            num_return_sequences=2,
            do_sample=True,
            temperature=0.8,
            top_k=50,
            top_p=0.95
        )

        for index, output in enumerate(results):

            print(f"\nGenerated Text {index+1}")
            print("-" * 40)

            generated_text = output['generated_text']

            print(generated_text)

            with open("outputs.txt", "a") as file:
                file.write(generated_text)
                file.write("\n\n")

    except Exception as e:

        print("Error:", e)
