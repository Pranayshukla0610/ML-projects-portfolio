# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranayshukla0610/ML-projects-portfolio/blob/main/Python_Logical_Practice_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Check Whether Two Strings are Anagrams

str1 = input("Enter first string:").lower()
str2 = input("Enter second string:").lower()

if sorted(str1) == sorted(str2):
  print("The string is Anagram")
else:
  print("The string is not Anagram")
# Out:
# Enter first string:silent
# Enter second string:listen
# The string is Anagram

# %%
#Reverse a String

str = input("Enter a string:")
print(str[::-1])
# Out:
# Enter a string:silent
# tnelis

# %%
text = input("Enter a string:")
reverse = ""

for char in text:
  reverse = char + reverse

print(reverse)
# Out:
# Enter a string:silent
# tnelis

# %%
#Check Whether a String is a Palindrome

str = input("Enter a string:")

str = str.lower()

if str == str[::-1]:
  print("The string is a palindrome")
else:
  print("The string is not a palindrome")
# Out:
# Enter a string:silent
# The string is not a palindrome

# %%
#Count Vowels and Consonants

str = input("Enter a string:").lower()

vowels = 0
consonants = 0

for char in str:
  if char in 'aeiou':
    vowels += 1
  elif char.isalpha():
    consonants += 1

print("Vowels:",vowels)
print("Consonants:",consonants)
# Out:
# Enter a string:PranayShukla
# Vowels: 4
# Consonants: 8

# %%
#Count Uppercase and Lowercase Letters

str = input("Enter a string:")

uppercase = 0
lowercase = 0

for char in str:
  if char == char.lower():
    lowercase += 1
  else:
    uppercase += 1

print("UpperCase:",uppercase)
print("LowerCase:",lowercase)
# Out:
# Enter a string:Pranay Shukla
# UpperCase: 2
# LowerCase: 11

# %%
#Count Words in a Sentence

str = input("Enter a sentence:").split()

count = 0

for char in str:
  count += 1

print("Words Count:",count)
# Out:
# Enter a sentence:I Love Data Science
# Words Count: 4

# %%
#Remove Duplicate Characters

str = input("Enter a string:")

result = ""

for char in str:
  if char not in result:
    result += char

print(result)
# Out:
# Enter a string:resilient
# resilnt

# %%
#Find the Frequency of Each Character

text = input("Enter a string: ")

frequency = {}

for ch in text:
    frequency[ch] = frequency.get(ch, 0) + 1

print(frequency)
# Out:
# Enter a string: PranayShukla
# {'P': 1, 'r': 1, 'a': 3, 'n': 1, 'y': 1, 'S': 1, 'h': 1, 'u': 1, 'k': 1, 'l': 1}

# %%
#Find the First Non-Repeating Character

text = input("Enter a string:")

for char in text:
  if text.count(char) == 1:
    print("First Non-Repeating Character:",char)
    break
else:
  print("No Unique Character Found")
# Out:
# Enter a string:aabccde
# First Non-Repeating Character: b
