# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranayshukla0610/ML-projects-portfolio/blob/main/NLP_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
#Getting dataset
df = pd.read_csv('/content/mushrooms.csv')

# %%
df.shape
# Out:
# (8124, 23)

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
le = LabelEncoder()

# %%
df_encoded = df.apply(le.fit_transform,axis=0)

# %%
df_encoded.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                       7                       7          0           2
# 1                       7                       7          0           2
# 2                       7                       7          0           2
# 3                       7                       7          0           2
# 4                       7                       7          0           2
#
#    ring-number  ring-type  spore-print-color  population  habitat
# 0            1          4                  2           3        5
# 1            1          4                  3           2        1
# 2            1          4                  3           2        3
# 3            1          4                  2           3        5
# 4            1          0                  3           0        1
#
# [5 rows x 23 columns]

# %%
df = df_encoded.values

# %%
X = df[:, 1:]

# %%
y = df[:,0]

# %%
X
# Out:
# array([[5, 2, 4, ..., 2, 3, 5],
#        [5, 2, 9, ..., 3, 2, 1],
#        [0, 2, 8, ..., 3, 2, 3],
#        ...,
#        [2, 2, 4, ..., 0, 1, 2],
#        [3, 3, 4, ..., 7, 4, 2],
#        [5, 2, 4, ..., 4, 1, 2]])

# %%
y
# Out:
# array([1, 0, 0, ..., 0, 1, 0])

# %%
X_train, y_train, X_test, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42
)

# %% [markdown]
# #NAIVE BAYES CLASSIFIER
# ##Posterior Probability
# ##Likelihood Probability
# ##Prior Probability

# %%
def fix_shape(X):
    X = np.array(X)
    if len(X.shape) == 1:        # if shape = (n,)
        X = X.reshape(-1, 1)     # reshape to (n,1)
    return X

# %%
X_train = fix_shape(X_train)
X_test  = fix_shape(X_test)

# Make sure both have same number of features
if X_train.shape[1] != X_test.shape[1]:
    X_test = X_test.reshape(-1, X_train.shape[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2169382872.py in <cell line: 0>()
#       4 # Make sure both have same number of features
#       5 if X_train.shape[1] != X_test.shape[1]:
# ----> 6     X_test = X_test.reshape(-1, X_train.shape[1])
#
# ValueError: cannot reshape array of size 6499 into shape (22)

# %%
# Prior Probability: P(label)
def prior_prob(y, label):
    m = y.shape[0]
    s = np.sum(y == label)
    return s / m

# %%
# Conditional Probability: P(feature_val | label) with Laplace smoothing
def cond_prob(X_train, y_train, feature_col, feature_val, label):
    X_filtered = X_train[y_train == label]
    num = np.sum(X_filtered[:, feature_col] == feature_val)

    # Laplace smoothing
    denom = X_filtered.shape[0]
    return (num + 1) / (denom + 2)   # "+2" since binary/multi-category features

# %%
# Predict one sample
def predict(X_train, y_train, x):
    classes = np.unique(y_train)
    n_features = X_train.shape[1]
    posterior_prob = []

    for label in classes:
        likelihood = 1.0

        for fea in range(n_features):
            cond = cond_prob(X_train, y_train, fea, x[fea], label)
            likelihood *= cond

        prior = prior_prob(y_train, label)
        posterior = likelihood * prior
        posterior_prob.append(posterior)

    return np.argmax(posterior_prob)

# %%
# Accuracy
def accuracy(X_train, y_train, X_test, y_test):
    pred = []
    for i in range(len(X_test)):
        pred.append(predict(X_train, y_train, X_test[i]))

    pred = np.array(pred)
    return np.mean(pred == y_test)

# %%
acc = accuracy(X_train, y_train, X_test, y_test)
acc
