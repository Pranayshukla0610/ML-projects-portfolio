# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranayshukla0610/ML-projects-portfolio/blob/main/AI_Generated_Future_Vehicles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install diffusers transformers accelerate safetensors torch torchvision pillow matplotlib -q

# %%
import torch
from diffusers import StableDiffusionPipeline
import matplotlib.pyplot as plt

# %%
print("CUDA Available:",torch.cuda.is_available())

# %%
model_id = 'runwayml/stable-diffusion-v1-5'

pipe = StableDiffusionPipeline.from_pretrained(
    model_id,
    torch_dtype = torch.float16
)

pipe = pipe.to('cuda')

# %%
prompt = """
futuristic electric hypercar,
cyberpunk design,
neon lights,
aerodynamic body,
ultra realistic,
concept vehicle,
high detail,
4k,
cinematic lighting
"""

# %%
negative_prompt = """
blurry,
low quality,
distorted wheels,
bad anatomy,
extra tires,
cropped image
"""

# %%
image = pipe(
    prompt = prompt,
    negative_prompt = negative_prompt,
    guidance_scale=8.5,
    num_inference_steps=40,
    height=512,
    width=512
).images[0]

# %%
plt.imshow(image)
plt.axis('off')
plt.title('AI Generated Future Vehicles')
plt.show()

# %%
image.save("future_vehicle.png")

print("Vehicle concept generated successfully!")

# %%
prompt2 = """
futuristic electric hyperbike,
cyberpunk design,
neon lights,
aerodynamic body,
ultra realistic,
concept vehicle,
high detail,
4k,
cinematic lighting
"""

# %%
negative_prompt = """
blurry,
low quality,
distorted wheels,
bad anatomy,
extra tires,
cropped image
"""

# %%
image2 = pipe(
    prompt = prompt2,
    negative_prompt = negative_prompt,
    guidance_scale=8.5,
    num_inference_steps=40,
    height=512,
    width=512
).images[0]

# %%
plt.imshow(image2)
plt.axis('off')
plt.title('AI Generated Future Vehicles')
plt.show()
